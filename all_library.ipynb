# %%
# Data Loader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import ArxivLoader
from langchain_community.document_loaders import WikipediaLoader

# text splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import CharacterTextSplitter
from langchain_text_splitters import HTMLHeaderTextSplitter
from langchain_text_splitters import RecursiveJsonSplitter

# Embedding
from langchain_openai import OpenAIEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.embeddings import OllamaEmbeddings

# A retriever is the component in a RAG system that finds the most relevant documents from vectore database for a query.

# vector Database
from langchain_community.vectorstores import FAISS      # FAISS is a high-performance vector similarity search library
from langchain_chroma import Chroma                     # Chroma is an embedding database

# chat prompt template
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder, PromptTemplate

# output parser
from langchain_core.output_parsers import StrOutputParser

# combines multiple documents into one prompt and sends it to an LLM
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_core.documents import Document


# it is a LangChain function that builds a RAG pipeline
from langchain_classic.chains import create_retrieval_chain  #  It connects: Retriever (search documents) to LLM (answer using those documents)


# add_routes from LangServe is used to turn your LangChain app into API endpoints (FastAPI routes)
from langserve import add_routes

# messages
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage, trim_messages
# HumanMessage = Message sent by the user to the AI
# SystemMessage = Instruction for the AI
# AIMessage = AI response/answer
# trim messages = take a specific part from messages

# related to text store and connect memory to the model
from langchain_community.chat_message_histories import ChatMessageHistory #  <-- this class store chat messages
from langchain_core.chat_history import BaseChatMessageHistory # <--- used for type definition
from langchain_core.runnables.history import RunnableWithMessageHistory # <---- add memory/history to the model


from operator import itemgetter      # Used to extract a value from a dictionary

from langchain_core.runnables import RunnablePassthrough    # Passes data through the chain while allowing modification


# RAG = Take the user question, retrieve related documents from the vectore database, put both into a prompt, and send them to llm and let the LLM answer.


from langchain_classic.chains import create_history_aware_retriever  #  This utility creates a retriever that understands conversation history.

from langchain_core.prompts import MessagesPlaceholder  #  It is used inside LangChain prompt templates to insert chat history dynamically



from pathlib import Path # Helps work with file paths safely.

# Creates an AI agent that can understand and run SQL queries.
from langchain_community.agent_toolkits.sql.base import create_sql_agent

# Connects LangChain with a SQL database.
from langchain_community.utilities import SQLDatabase

# Defines the behavior/style of the AI agent.
from langchain_classic.agents.agent_types import AgentType

# Shows the agent’s thinking and actions in Streamlit.
from langchain_community.callbacks.streamlit import StreamlitCallbackHandler

# Provides database-related tools for the SQL agent.
from langchain_community.agent_toolkits import SQLDatabaseToolkit

# Creates a connection engine for databases using SQLAlchemy.
from sqlalchemy import create_engine

# import tool
from langchain_core.tools import Tool
#chain
from langchain_classic.chains import LLMMathChain, LLMChain


# chain for summarizing documents
from langchain_classic.chains.summarize import load_summarize_chain

# url loader
from langchain_community.document_loaders import YoutubeLoader, UnstructuredURLLoader

from langchain_classic.agents.initialize import initialize_agent

from langchain_classic.agents.agent_types import AgentType

# %%
#Simple RAG pipline


# Input Question
#       ↓
# "tell me about dogs"

#  ┌────────────────────┐
#  │                    │
#  ↓                    ↓

# Retriever          Passthrough
# (search docs)      (keep question)

#  ↓                    ↓

# "context"          "question"

#  └────────┬───────────┘
#           ↓

#        Prompt

#           ↓

#          LLM

#           ↓

#        Answer
