# %%
# quantization means converting higher memory format to lower memory format
# 1) symmetric quantiztion
# 2) ascymmetric quantization

# %%
# quantization aware technique
# train model -> quantization -> fine tuning using training data -> quantize model
