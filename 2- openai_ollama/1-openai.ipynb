# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model = "gpt-5-nano")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-5 Nano', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x1142137f0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x114e08850> root_client=<openai.OpenAI object at 0x10809af80> root_async_client=<openai.AsyncOpenAI object at 0x114210b20> model_name='gpt-5-nano' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
## input and get response from llm

response = llm.invoke("What is generative ai?")

# %%
print(response.content)
# Out:
# Generative AI refers to a branch of artificial intelligence that can create new content—text, images, music, code, video, and more—rather than just analyze or classify existing data.
#
# Key ideas:
# - What it does: It learns patterns from large amounts of data and then samples from what it learned to produce new, original content that resembles the training data.
# - How it does it (at a high level):
#   - Autoregressive models (like many language models) generate data one piece at a time (word by word or token by token), predicting the next piece from what’s come before.
#   - Diffusion models progressively refine random noise into a coherent image or video.
#   - Other approaches include GANs (generative adversarial networks) and VAEs (variational autoencoders).
# - Examples:
#   - Text: ChatGPT, GPT-4, other large language models that write essays, summarize, or translate.
#   - Images: DALL-E, Stable Diffusion, Midjourney that create pictures from text prompts.
#   - Code: Copilot and similar tools that generate or autocomplete code.
#   - Music/audio: systems that compose melodies or generate sound effects.
#   - Video/design: tools that generate or edit video and 3D assets.
# - How it’s used: content creation, rapid prototyping, design exploration, data augmentation, education, accessibility, and more.
# - Important caveats:
#   - Outputs can be incorrect or “hallucinate” facts.
#   - They can reflect biases or harmful patterns from training data.
#   - Copyright and licensing concerns around generated content and training data.
#   - They can be computationally intensive and require careful prompting and safety controls.
#
# If you want, I can tailor this to a specific domain (e.g., text, images, code) or walk through a concrete example.

# %%
## chatprompt Template

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
       ("system","You are an expert AI Engineer. Provide me answers based on the question"),
       ("user","{input}") 
    ]
)

# %%
## chain

chain = prompt | llm

response = chain.invoke({"input":"Can you tell me about image segmentation model?"})

print(response)
# Out:
# content='Here’s a concise overview of image segmentation models and how they’re used.\n\nWhat is image segmentation?\n- The task of labeling each pixel in an image with a category (semantic) or with an object instance (instance). There’s also panoptic segmentation, which combines both semantics and instance IDs.\n\nTypes of segmentation\n- Semantic segmentation: assign a class label to every pixel. All objects of the same class share the same label (e.g., all cars labeled “car” together).\n- Instance segmentation: detect and delineate each object separately, giving each instance its own mask in addition to its class.\n- Panoptic segmentation: combines semantic and instance segmentation, providing both per-pixel class labels and distinct instance IDs for object classes.\n\nCommon architectures and ideas\n- Encoder–decoder models (often with skip connections)\n  - U-Net, SegNet, DeepLabv3+/PSPNet-style backbones: encoder extracts features; decoder (and sometimes upsampling) produces a pixel-wise map.\n- Dilated/convolutional pyramids\n  - DeepLabv3+ (ASPP with atrous/dilated convolutions), PSPNet (pyramid pooling). These capture multi-scale context without heavy downsampling.\n- Multi-scale / high-resolution backbones\n  - HRNet maintains high-resolution representations and fuses multi-scale information for precise boundaries.\n- Lightweight / real-time\n  - BiSeNet, ENet, DDRNet. Trade accuracy for speed/memory suitable for edge devices.\n- Instance segmentation\n  - Mask R-CNN: backbone + region proposals + per-object masks.\n  - YOLACT, CondInst, BlendMask: real-time or near-real-time instance segmentation with different design trade-offs.\n- Panoptic segmentation\n  - Panoptic FPN, UPSNet, EfficientPS: unify semantic and instance predictions into a single output.\n- Transformer-based / modern backbones\n  - SegFormer, transformer-inspired variants (often with strong contextual modeling and good scalability).\n\nRepresentative datasets (to judge what you’ll train on)\n- PASCAL VOC, COCO (common for general segmentation and instance tasks)\n- Cityscapes (urban scenes, high-quality road/object boundaries)\n- ADE20K (diverse set of scenes/classes)\n- Medical imaging datasets (BraTS, ISBI, etc., if you’re in healthcare)\n- Satellite imagery (various remote sensing datasets)\n\nLosses and evaluation metrics\n- Losses: cross-entropy, dice (also called F1 or Sørensen–Dice), focal loss (helps with class imbalance), IoU-based losses, boundary losses for sharp edges.\n- Evaluation metrics:\n  - Semantic: mean IoU (mIoU) across classes, pixel accuracy.\n  - Instance: Average Precision (AP) at various IoU thresholds (AP50, AP75, etc.).\n  - Panoptic: Panoptic Quality (PQ), which combines segmentation quality and recognition quality.\n\nTraining and practical tips\n- Pretraining: use a strong backbone pretrained on ImageNet (or larger, e.g., ViT backbones) to improve convergence.\n- Data augmentation: scale jittering, cropping, flipping, color jitter, random rotations; mixup or CutMix can help generalization.\n- Class imbalance: use dice loss or focal loss, or implement class weighting.\n- Multi-scale training/inference: helps with objects at different sizes; many architectures inherently support multi-scale features.\n- Post-processing: sometimes CRFs or simple thresholding help refine boundaries (less common with modern networks but still useful in some domains).\n- Hardware considerations: choose a backbone and model size to fit your GPU memory and real-time requirements.\n\nHow to choose a model for a task\n- Medical image segmentation: U-Net family, 3D variants (for volume data), attention U-Nets; dice loss is common.\n- Autonomous driving / street scenes: DeepLabV3+/ResNet or HRNet-based approaches; Cityscapes-like metrics emphasize boundary accuracy.\n- Real-time applications on devices: BiSeNet, ENet, YOLACT-like instance methods with fast backbones.\n- General-purpose semantic segmentation: DeepLabV3+/PSPNet with HRNet or SegForm ...

# %%
print(response.content)
# Out:
# Here’s a concise overview of image segmentation models and how they’re used.
#
# What is image segmentation?
# - The task of labeling each pixel in an image with a category (semantic) or with an object instance (instance). There’s also panoptic segmentation, which combines both semantics and instance IDs.
#
# Types of segmentation
# - Semantic segmentation: assign a class label to every pixel. All objects of the same class share the same label (e.g., all cars labeled “car” together).
# - Instance segmentation: detect and delineate each object separately, giving each instance its own mask in addition to its class.
# - Panoptic segmentation: combines semantic and instance segmentation, providing both per-pixel class labels and distinct instance IDs for object classes.
#
# Common architectures and ideas
# - Encoder–decoder models (often with skip connections)
#   - U-Net, SegNet, DeepLabv3+/PSPNet-style backbones: encoder extracts features; decoder (and sometimes upsampling) produces a pixel-wise map.
# - Dilated/convolutional pyramids
#   - DeepLabv3+ (ASPP with atrous/dilated convolutions), PSPNet (pyramid pooling). These capture multi-scale context without heavy downsampling.
# - Multi-scale / high-resolution backbones
#   - HRNet maintains high-resolution representations and fuses multi-scale information for precise boundaries.
# - Lightweight / real-time
#   - BiSeNet, ENet, DDRNet. Trade accuracy for speed/memory suitable for edge devices.
# - Instance segmentation
#   - Mask R-CNN: backbone + region proposals + per-object masks.
#   - YOLACT, CondInst, BlendMask: real-time or near-real-time instance segmentation with different design trade-offs.
# - Panoptic segmentation
#   - Panoptic FPN, UPSNet, EfficientPS: unify semantic and instance predictions into a single output.
# - Transformer-based / modern backbones
#   - SegFormer, transformer-inspired variants (often with strong contextual modeling and good scalability).
#
# Representative datasets (to judge what you’ll train on)
# - PASCAL VOC, COCO (common for general segmentation and instance tasks)
# - Cityscapes (urban scenes, high-quality road/object boundaries)
# - ADE20K (diverse set of scenes/classes)
# - Medical imaging datasets (BraTS, ISBI, etc., if you’re in healthcare)
# - Satellite imagery (various remote sensing datasets)
#
# Losses and evaluation metrics
# - Losses: cross-entropy, dice (also called F1 or Sørensen–Dice), focal loss (helps with class imbalance), IoU-based losses, boundary losses for sharp edges.
# - Evaluation metrics:
#   - Semantic: mean IoU (mIoU) across classes, pixel accuracy.
#   - Instance: Average Precision (AP) at various IoU thresholds (AP50, AP75, etc.).
#   - Panoptic: Panoptic Quality (PQ), which combines segmentation quality and recognition quality.
#
# Training and practical tips
# - Pretraining: use a strong backbone pretrained on ImageNet (or larger, e.g., ViT backbones) to improve convergence.
# - Data augmentation: scale jittering, cropping, flipping, color jitter, random rotations; mixup or CutMix can help generalization.
# - Class imbalance: use dice loss or focal loss, or implement class weighting.
# - Multi-scale training/inference: helps with objects at different sizes; many architectures inherently support multi-scale features.
# - Post-processing: sometimes CRFs or simple thresholding help refine boundaries (less common with modern networks but still useful in some domains).
# - Hardware considerations: choose a backbone and model size to fit your GPU memory and real-time requirements.
#
# How to choose a model for a task
# - Medical image segmentation: U-Net family, 3D variants (for volume data), attention U-Nets; dice loss is common.
# - Autonomous driving / street scenes: DeepLabV3+/ResNet or HRNet-based approaches; Cityscapes-like metrics emphasize boundary accuracy.
# - Real-time applications on devices: BiSeNet, ENet, YOLACT-like instance methods with fast backbones.
# - General-purpose semantic segmentation: DeepLabV3+/PSPNet with HRNet or SegFormer for strong context modeling.
# - Instance segmentation needs: Mask R-CNN for accuracy, YOLACT/CondInst for real-time; for panoptic tasks, look at Panoptic FPN or UPSNet.
#
# Starter roadmap
# - Define your task clearly: semantic vs instance vs panoptic; identify speed vs accuracy constraints.
# - Pick a dataset or domain (e.g., Cityscapes for driving, medical images for healthcare).
# - Start with a strong, well-supported baseline:
#   - Semantic: DeepLabv3+ with a ResNet or EfficientNet backbone.
#   - Instance: Mask R-CNN with a good backbone.
#   - Panoptic: Panoptic FPN or UPSNet.
# - Use a reputable framework with good community support:
#   - PyTorch with Detectron2 (for instance and panoptic), MMSegmentation (OpenMMLab) for semantic/panoptic, or SegFormer implementations.
#   - TensorFlow/Keras options exist but are less dominant in some segmentation tasks.
# - Fine-tune on your data, use transfer learning, and monitor mIoU/AP metrics on a validation set. Iterate on backbones, loss functions, and data augmentation.
#
# If you share your domain (medicine, autonomous driving, aerial imagery, general photos, etc.), your target accuracy/speed needs, and hardware, I can recommend a concrete model and a simple starter workflow, including a suggested training plan and evaluation setup.

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput parser

from langchain_core.output_parsers import StrOutputParser

output_parse  = StrOutputParser()

chain = prompt | llm | output_parse

response = chain.invoke({"input":"Can you tell me about Langsmith?"})

# %%
print(response)
# Out:
# LangSmith is an observability/debugging platform for AI apps, especially those built with language models. It’s developed by the LangChain ecosystem and is designed to help you capture, inspect, compare, and reproduce LLM runs so you can improve prompts, test behavior, and monitor performance in production.
#
# What LangSmith does
# - Record runs: automatically or manually log inputs, model, prompts/templates, parameters, outputs, token usage, latency, and other metadata.
# - Reproduce and replay: re-run a recorded run to reproduce results and verify fixes.
# - Analysis and dashboards: view and filter runs by model, prompt, user, or metadata; track latency, cost, accuracy, error rates, and other metrics.
# - Evaluation and testing: set up automated checks or human evaluations to gate model outputs and measure quality over time or across model versions.
# - Collaboration: share runs, annotate findings, and compare different prompts or configurations with teammates.
# - Integrations: works well with LangChain via callback/logging hooks, and can also be used with non-LangChain setups through its SDK.
#
# Who should use LangSmith
# - Prompt engineers and ML engineers who want to iteratively refine prompts and prompts templates.
# - Teams that need reproducibility and audit trails for model behavior (e.g., compliance or quality assurance).
# - Anyone monitoring production LLM apps for performance, drift, or cost.
#
# How it typically works (high level)
# - Sign up and get an API key for LangSmith.
# - Instrument your code:
#   - If you’re using LangChain, attach a LangSmith callback/handler so each LLM call is automatically logged.
#   - If you’re not using LangChain, use LangSmith’s SDK to log runs with inputs, outputs, and metadata.
# - Run your app in development or production; LangSmith stores the run data in a workspace.
# - Open the LangSmith web UI to explore runs, compare variations, drill into specific prompts, and replay runs to validate fixes.
# - Define evaluations or tests to automatically score outputs or flag undesired results.
#
# Getting started (quick ideas)
# - If you use LangChain: install the LangSmith integration, attach the LangSmith callback to your LLM/Chains, and start logging.
# - If you’re not using LangChain: install the LangSmith SDK, create a run, log inputs/outputs/metrics, and end the run.
# - Explore the UI to filter by model, prompt, or user, and use the replay feature to reproduce outcomes.
#
# Common use cases
# - Prompt optimization: compare many prompt variants side-by-side and identify which yields the best results.
# - Model/version comparison: evaluate how different models or versions affect outputs and costs.
# - Reliability monitoring: track latency, errors, and drift over time; set up alerts.
# - Compliance and auditing: maintain an auditable trail of inputs/outputs for difficult or regulated domains.
#
# If you’d like, I can give you a quick starter guide tailored to your stack (e.g., Python with OpenAI API, or LangChain in Python/Node), plus example steps or minimal code snippets to get you going.
