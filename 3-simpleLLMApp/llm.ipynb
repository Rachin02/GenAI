# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI

# %%
gpt_llm=ChatOpenAI(model = "gpt-5-nano")
print(gpt_llm)
# Out:
# output_version=None profile={'name': 'GPT-5 Nano', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x114537fa0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11522ca30> root_client=<openai.OpenAI object at 0x114537c70> root_async_client=<openai.AsyncOpenAI object at 0x11462cfd0> model_name='gpt-5-nano' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
gemini_llm = ChatGoogleGenerativeAI(model = "gemini-3-flash-preview")
print(gemini_llm)
# Out:
# output_version=None profile={'name': 'Gemini 3 Flash Preview', 'release_date': '2025-12-17', 'last_updated': '2025-12-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True} google_api_key=SecretStr('**********') location=None model='gemini-3-flash-preview' temperature=1.0 client=<google.genai.client.Client object at 0x114537eb0> default_metadata=() model_kwargs={}

# %%
response = gpt_llm.invoke("what core topic we need to know to become machine learning engineer?")

print(response)
# Out:
# content='Great question. A machine learning engineer needs a mix of math, programming, ML theory, and software engineering / MLOps skills. Here’s a structured map of the core topics and a practical learning path.\n\nCore topic areas\n\n- Math and statistics\n  - Linear algebra (vectors, matrices, eigenvalues, factorization)\n  - Calculus (gradients, optimization, chain rule)\n  - Probability and statistics (distributions, Bayesian reasoning, hypothesis testing)\n  - Optimization basics (gradient descent, regularization, convexity concepts)\n\n- Programming and software engineering\n  - Python fundamentals and scientific stack (NumPy, Pandas, SciPy)\n  - Data structures and algorithms\n  - Software engineering practices (version control with Git, testing, debugging, tracing, documentation)\n  - APIs and basic software design patterns\n\n- Core machine learning concepts\n  - Supervised vs unsupervised vs reinforcement learning\n  - Regression, classification, clustering, evaluation metrics (accuracy, F1, ROC-AUC, RMSE, etc.)\n  - Feature engineering and data preprocessing\n  - Model selection, cross-validation, hyperparameter tuning\n  - Intro to neural networks: MLPs, CNNs, RNNs; basics of transformers\n  - Transfer learning and fine-tuning\n\n- ML systems, data engineering, and pipelines\n  - Data wrangling, cleaning, and feature stores\n  - Data versioning, experiment tracking (e.g., MLflow, Weights & Biases)\n  - End-to-end pipelines: data ingestion → preprocessing → modeling → evaluation\n  - Model deployment basics (REST APIs, endpoints)\n  - Model serving options (TorchServe, TF Serving) and inference optimization\n  - Monitoring, logging, and drift detection; reproducibility\n\n- MLOps, deployment, and operations\n  - CI/CD concepts for ML\n  - Containerization and orchestration (Docker, Kubernetes)\n  - Cloud platforms (AWS, GCP, Azure) and managed ML services\n  - Scaling for training and inference (distributed training basics, mixed precision)\n  - Security, privacy, and governance (data leakage, model bias, compliance)\n\n- Domain knowledge and ethics\n  - Understanding the problem domain you’re solving (finance, healthcare, e-commerce, etc.)\n  - Ethics, fairness, bias reduction, data privacy considerations\n\n- Practical soft skills\n  - Building end-to-end projects that demonstrate from data to product\n  - Communicating results to non-technical stakeholders\n  - Reproducibility and documentation\n\nSuggested learning path (practical plan)\n\n- 0–3 months (foundations)\n  - Strengthen Python fluency; learn NumPy, Pandas\n  - Linear algebra, basic statistics, and simple probability\n  - Intro to ML with scikit-learn: regression, classification, basic evaluation\n  - Build 1–2 small end-to-end projects (e.g., a tabular data predictor, a basic image/classification task with a simple model)\n\n- 3–6 months (core ML and simple systems)\n  - Deepen ML understanding: regularization, cross-validation, feature engineering\n  - Learn PyTorch or TensorFlow; implement basic neural networks\n  - Start a small end-to-end project that includes training a model and exposing it via a simple API (Flask or FastAPI)\n  - Learn versioning and experiment tracking basics\n\n- 6–12 months (ML systems and deployment)\n  - Learn Docker basics; deploy models with a containerized API\n  - Explore cloud platforms and simple MLOps concepts (CI/CD for ML, basic monitoring)\n  - Get comfortable with distributed training concepts (even if hands-on is light)\n  - Build a substantial project that showcases data pipeline, model training, evaluation, deployment, and monitoring\n  - Start building a portfolio and documenting lessons learned\n\nRecommended resources (popular starting points)\n\n- Courses (beginner to intermediate)\n  - Andrew Ng’s Machine Learning (math + ML intuition)\n  - Deep Learning Specialization or Practical Deep Learning for Coders (fast.ai) for hands-on DL\n  - CS231n (Convolutional Neural Networks for Visual Recognition) for  ...

# %%
response = gemini_llm.invoke("what core topic we need to know to become machine learning engineer?")
print(response)
# Out:
# content=[{'type': 'text', 'text': 'Becoming a Machine Learning Engineer (MLE) requires a unique blend of **Data Science**, **Software Engineering**, and **Mathematics**. Unlike a Data Scientist who focuses on insights, an MLE focuses on building, deploying, and scaling production-ready models.\n\nHere are the core topics you need to master, organized by category:\n\n---\n\n### 1. Mathematics & Statistics (The Foundation)\nYou don’t need to be a mathematician, but you must understand the "why" behind the algorithms.\n*   **Linear Algebra:** Matrix multiplication, Eigenvalues/Eigenvectors, Principal Component Analysis (PCA).\n*   **Calculus:** Derivatives, Gradients, and Chain Rule (essential for understanding Backpropagation).\n*   **Probability & Statistics:** Bayes’ Theorem, probability distributions (Gaussian, Bernoulli), hypothesis testing, and p-values.\n*   **Optimization:** Gradient Descent, Stochastic Gradient Descent (SGD), and Adam optimization.\n\n### 2. Programming & Software Engineering (The "Engineer" part)\nThis is what separates an MLE from a researcher.\n*   **Python:** The industry standard. You must be proficient in Object-Oriented Programming (OOP) and writing clean, PEP8-compliant code.\n*   **Data Structures & Algorithms:** Arrays, Linked Lists, Trees, Hash Maps, and Big O notation (crucial for optimizing model performance).\n*   **Version Control:** Git and GitHub/GitLab.\n*   **API Development:** Building REST APIs (FastAPI or Flask) to serve your models to other applications.\n*   **Testing:** Unit testing and integration testing for ML pipelines.\n\n### 3. Data Handling & Analysis\n*   **SQL:** Essential for extracting data from relational databases.\n*   **Data Manipulation Libraries:** Mastering **Pandas** and **NumPy** for data cleaning and transformation.\n*   **Feature Engineering:** Handling missing values, encoding categorical variables (One-Hot, Label encoding), scaling, and normalization.\n*   **Data Visualization:** Matplotlib, Seaborn, or Plotly (mostly for exploratory data analysis).\n\n### 4. Machine Learning Fundamentals\n*   **Supervised Learning:** Linear Regression, Logistic Regression, Decision Trees, Random Forests, and Gradient Boosting (XGBoost, LightGBM).\n*   **Unsupervised Learning:** K-Means Clustering, Hierarchical Clustering, and Dimensionality Reduction (PCA, t-SNE).\n*   **Evaluation Metrics:** Precision, Recall, F1-Score, ROC-AUC, Mean Squared Error (MSE), and R-squared.\n*   **Bias-Variance Tradeoff:** Understanding Overfitting vs. Underfitting and Regularization (L1/Lasso, L2/Ridge).\n\n### 5. Deep Learning (Neural Networks)\n*   **Core Concepts:** Artificial Neural Networks (ANNs), Activation Functions (ReLU, Sigmoid, Softmax).\n*   **Architectures:** \n    *   **CNNs** (Convolutional Neural Networks) for Computer Vision.\n    *   **RNNs/LSTMs** and **Transformers** (like BERT/GPT) for Natural Language Processing (NLP).\n*   **Frameworks:** Mastery of either **PyTorch** (highly recommended) or **TensorFlow/Keras**.\n\n### 6. MLOps & Deployment (The Modern Core)\nThis is currently the most in-demand skill set for MLEs.\n*   **Model Deployment:** Using **Docker** to containerize models and **Kubernetes** for orchestration.\n*   **Cloud Platforms:** AWS (SageMaker), Google Cloud (Vertex AI), or Azure ML.\n*   **CI/CD for ML:** Automated pipelines to retrain and redeploy models (GitHub Actions, Jenkins).\n*   **Model Monitoring:** Tracking model drift (performance decay over time) and data drift.\n*   **Experiment Tracking:** Tools like **MLflow** or **Weights & Biases** to keep track of different model versions.\n\n### 7. Big Data Tools (Optional but helpful)\n*   **Distributed Computing:** Spark (PySpark) for processing massive datasets that don\'t fit in RAM.\n*   **NoSQL Databases:** MongoDB or Cassandra.\n\n---\n\n### Recommended Learning Path\n1.  **Phase 1:** Learn Python and basic Math (Linear Algebra/Stats).\n2.  **Phase 2:** Master the Scikit-learn library for "Cl ...
