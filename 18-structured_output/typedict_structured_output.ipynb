# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI
from typing import List, Optional, Literal, TypedDict, Annotated

# %%
model = ChatOpenAI(model = "gpt-5.4-nano")

# %%
class Review(TypedDict):
    key_theme: Annotated[List[str], "write down all the key themes inside the review in a list"]
    summary: Annotated[str,"summarise the whole review in few sentences" ]
    sentiments: Annotated[ Literal["pos","neg"], "define the sentiment of the review in positive , negative and neutral "]
    pros: Annotated[List[str], "write down all the pros of the review in a list"]
    reviever: Annotated[str,"Write down the name of the reviewer" ]

# %%
structured_model = model.with_structured_output(Review)

# %%
input_txt = """ 
I recently upgraded to the Samsung Galaxy S24 Ultra, and I must say, it’s an absolute powerhouse! The Snapdragon 8 Gen 3 processor makes everything lightning fast—whether I’m gaming, multitasking, or editing photos. The 5000mAh battery easily lasts a full day even with heavy use, and the 45W fast charging is a lifesaver.

The S-Pen integration is a great touch for note-taking and quick sketches, though I don't use it often. What really blew me away is the 200MP camera—the night mode is stunning, capturing crisp, vibrant images even in low light. Zooming up to 100x actually works well for distant objects, but anything beyond 30x loses quality.

However, the weight and size make it a bit uncomfortable for one-handed use. Also, Samsung’s One UI still comes with bloatware—why do I need five different Samsung apps for things Google already provides? The $1,300 price tag is also a hard pill to swallow.

Pros:
Insanely powerful processor (great for gaming and productivity)
Stunning 200MP camera with incredible zoom capabilities
Long battery life with fast charging
S-Pen support is unique and useful
                                 
Review by Rachin
"""

# %%
response = structured_model.invoke(input_txt)

# %%
print(response)
# Out:
# {'key_theme': ['performance', 'camera quality', 'battery and charging', 'S-Pen features', 'design comfort', 'software/bloatware', 'pricing'], 'summary': 'The Samsung Galaxy S24 Ultra is praised for its top-tier Snapdragon performance, impressive 200MP camera (especially night mode and up to 100x zoom), and excellent battery life with 45W fast charging, with added value from S-Pen support. However, its large weight makes one-handed use uncomfortable, One UI is criticized for bloatware, and the $1,300 price is considered too high.', 'sentiments': 'pos', 'pros': ['Insanely powerful Snapdragon 8 Gen 3 performance for gaming and productivity', 'Stunning 200MP camera and impressive night mode results', 'Strong battery life with 45W fast charging', 'S-Pen integration adds useful note-taking and sketching functionality'], 'reviever': 'Rachin'}

# %%
print(type(response))
# Out:
# <class 'dict'>

# %%
print(response['reviever'])
# Out:
# Rachin

# %%
print(response['sentiments'])
# Out:
# pos
