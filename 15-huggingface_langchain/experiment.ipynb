# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
repo = "google/flan-t5-large""
llm = HuggingFaceEndpoint(repo_id= repo,temperature= 0.7, huggingfacehub_api_token= os.getenv("HF_TOKEN"))

# %%
llm.invoke("WHat is machine learning")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 llm.invoke("WHat is machine learning")
#
# File ~/Desktop/GenAI/genai/lib/python3.10/site-packages/langchain_core/language_models/llms.py:381, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     370 @override
#     371 def invoke(
#     372     self,
#    (...)
#     377     **kwargs: Any,
#     378 ) -> str:
#     379     config = ensure_config(config)
#     380     return (
# --> 381         self.generate_prompt(
#     382             [self._convert_input(input)],
#     383             stop=stop,
#     384             callbacks=config.get("callbacks"),
#     385             tags=config.get("tags"),
#     386             metadata=config.get("metadata"),
#     387             run_name=config.get("run_name"),
#     388             run_id=config.pop("run_id", None),
# ...
